# %%
import pandas as pd
countries_df = pd.read_csv("data/countries_df.csv")
continents_df = pd.read_csv("data/continents_df.csv")
income_types_df = pd.read_csv("data/income_types_df.csv")

# %%
countries_df
# Out:
#             Entity Code  Year  Annual CO₂ emissions  \
# 0      Afghanistan  AFG  1850                   NaN
# 1      Afghanistan  AFG  1851                   NaN
# 2      Afghanistan  AFG  1852                   NaN
# 3      Afghanistan  AFG  1853                   NaN
# 4      Afghanistan  AFG  1854                   NaN
# ...            ...  ...   ...                   ...
# 37813     Zimbabwe  ZWE  2017             9596071.0
# 37814     Zimbabwe  ZWE  2018            11795478.0
# 37815     Zimbabwe  ZWE  2019            11114607.0
# 37816     Zimbabwe  ZWE  2020            10607897.0
# 37817     Zimbabwe  ZWE  2021            11296114.0
#
#        Annual CO₂ emissions including land-use change  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...

# %%
continents_df
# Out:
#              Entity  Code  Year  Annual CO₂ emissions  \
# 0            Africa   NaN  1850          0.000000e+00
# 1            Africa   NaN  1851          0.000000e+00
# 2            Africa   NaN  1852          0.000000e+00
# 3            Africa   NaN  1853          0.000000e+00
# 4            Africa   NaN  1854          0.000000e+00
# ...             ...   ...   ...                   ...
# 1199  South America   NaN  2017          1.125113e+09
# 1200  South America   NaN  2018          1.064608e+09
# 1201  South America   NaN  2019          1.073178e+09
# 1202  South America   NaN  2020          9.811897e+08
# 1203  South America   NaN  2021          1.074998e+09
#
#       Annual CO₂ emissions including land-use change  \
# 0                                       1.856549e+08
# 1                                       2.495184e+08
# 2                                       2.879904e+08
# 3                                       3.194642e+08
# ...

# %%
income_types_df
# Out:
#                             Entity  Code  Year  Annual CO₂ emissions  \
# 0            High-income countries   NaN  1850          1.967855e+08
# 1            High-income countries   NaN  1851          1.988050e+08
# 2            High-income countries   NaN  1852          2.075509e+08
# 3            High-income countries   NaN  1853          2.172092e+08
# 4            High-income countries   NaN  1854          2.551390e+08
# ..                             ...   ...   ...                   ...
# 683  Upper-middle-income countries   NaN  2017          1.558603e+10
# 684  Upper-middle-income countries   NaN  2018          1.596471e+10
# 685  Upper-middle-income countries   NaN  2019          1.633844e+10
# 686  Upper-middle-income countries   NaN  2020          1.621984e+10
# 687  Upper-middle-income countries   NaN  2021          1.703882e+10
#
#      Annual CO₂ emissions including land-use change  \
# 0                                      1.239853e+09
# ...
