# %% [markdown]
# ## CO2 Emissions Data
#
# Data from: [OWID](https://ourworldindata.org/explorers/co2?facet=none&country=CHN~USA~IND~GBR~OWID_WRL&Gas+or+Warming=CO%E2%82%82&Accounting=Production-based&Fuel+or+Land+Use+Change=All+fossil+emissions&Count=Per+country)

# %%
# This file contains several measurements including total emissions (co2) per year, per capita (co2_per_capita)
# and cumulative (cumulative_co2) 
# It is for all countries and also political/geographical regions including the World

import pandas as pd
df0 = pd.read_csv('owid-co2-data.csv')

# %%
# The codebook for the file above
codebook = pd.read_csv('owid-co2-codebook.csv')
codebook
# Out:
#                          column  \
# 0                       country
# 1                          year
# 2                      iso_code
# 3                    population
# 4                           gdp
# ..                          ...
# 74  temperature_change_from_n2o
# 75                    total_ghg
# 76     total_ghg_excluding_lucf
# 77                    trade_co2
# 78              trade_co2_share
#
#                                           description  \
# 0                                Geographic location.
# 1                                Year of observation.
# 2     ISO 3166-1 alpha-3, three-letter country codes.
# 3                     Population by country and year.
# 4   Gross domestic product measured in internation...
# ..                                                ...
# 74  Change in global mean surface temperature (in ...
# 75  Total greenhouse gas emissions including land-...
# 76  Total greenhouse gas emissions excluding land-...
# 77  Annual net carbon dioxide (CO₂) emissions embe...
# 78  Share of annual CO₂ emissions embedded in trad...
#
#                                                source
# 0                                   Our World in Data
# 1                                   Our World in Data
# 2      International Organization for Standardization
# 3   Population based on various sources (2023) [ht...
# 4   Maddison Project Database 2020 (Bolt and van Z...
# ..                                                ...
# 74  Jones et al. (2023) [https://zenodo.org/record...
# 75  Climate Watch - Greenhouse gas emissions by se...
# 76  Climate Watch - Greenhouse gas emissions by se...
# 77  Global Carbon Budget (2022) [https://globalcar...
# 78  Global Carbon Budget (2022) [https://globalcar...
#
# [79 rows x 3 columns]

# %% [markdown]
# ### Countries only CO2 data
# not regions

# %%
# This file has a subset of the data and only for countries
# we are going to use it to get the top 50 emitting countries

import pandas as pd
df2 = pd.read_csv('countries_df.csv')

# %%
# Sort the df by co2 emissions in 2021
df2021 = df2[df2['Year']==2021].sort_values(by = 'Annual CO₂ emissions', ascending=False)
all_countries = df2021['Entity']
# save it (just in case)
df2021.to_csv('CO2_2021_ordered.csv')
# get the top 50 and extract the country names
df2021_top20 = df2021.head(20)
countries = df2021_top20['Entity']
countries
# Out:
# 6956              China
# 35676     United States
# 15518             India
# 27491            Russia
# 17066             Japan
# 15862              Iran
# 12766           Germany
# 29081      Saudi Arabia
# 15690         Indonesia
# 31032       South Korea
# 6096             Canada
# 4832             Brazil
# 34300            Turkey
# 30860      South Africa
# 21436            Mexico
# 2008          Australia
# 35504    United Kingdom
# 16722             Italy
# 26459            Poland
# 36708           Vietnam
# Name: Entity, dtype: object

# %%
# Now use the country list to filter the original data for the top 50 emitters

df0_Top20 = df0[df0['country'].isin(countries)]
df0_Top20.info()
lst=['country','year','co2','co2_per_capita','population']
data = df0_Top20[df0_Top20.columns.intersection(lst)]
data[3600:3650]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3867 entries, 3498 to 49466
# Data columns (total 79 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   country                                    3867 non-null   object
#  1   year                                       3867 non-null   int64
#  2   iso_code                                   3867 non-null   object
#  3   population                                 3755 non-null   float64
#  4   gdp                                        2527 non-null   float64
#  5   cement_co2                                 2012 non-null   float64
#  6   cement_co2_per_capita                      2012 non-null   float64
#  7   co2                                        3336 non-null   float64
#  8   co2_growth_abs                             3308 non-null   float64
#  9   co2_growth_prct                            3223 non-null   float64
#  10  co2_including_luc                          2909 non-null   float64
#  11  co2_including_luc_growth_abs               2882 non-null   float64
#  12  co2_including_luc_growth_prct              2916 non-null   float64
#  13  co2_including_luc_per_capita               2909 non-null   float64
#  14  co2_including_luc_per_gdp                  2332 non-null   float64
#  15  co2_including_luc_per_unit_energy          1120 non-null   float64
#  16  co2_per_capita                             3224 non-null   float64
#  17  co2_per_gdp                                2427 non-null   float64
#  18  co2_per_unit_energy                        1120 non-null   float64
#  19  coal_co2                                   3330 non-null   float64
#  20  coal_co2_per_capita                        3218 non-null   float64
#  21  consumption_co2                            620 non-null    float64
#  22  consumption_co2_per_capita                 620 non-null    float64
#  23  consumption_co2_per_gdp                    580 non-null    float64
#  24  cumulative_cement_co2                      2012 non-null   float64
#  25  cumulative_co2                             3336 non-null   float64
#  26  cumulative_co2_including_luc               2909 non-null   float64
#  27  cumulative_coal_co2                        3330 non-null   float64
#  28  cumulative_flaring_co2                     3336 non-null   float64
#  29  cumulative_gas_co2                         3336 non-null   float64
#  30  cumulative_luc_co2                         3440 non-null   float64
#  31  cumulative_oil_co2                         3336 non-null   float64
#  32  cumulative_other_co2                       532 non-null    float64
#  33  energy_per_capita                          1120 non-null   float64
#  34  energy_per_gdp                             1060 non-null   float64
#  35  flaring_co2                                3336 non-null   float64
#  36  flaring_co2_per_capita                     3224 non-null   float64
#  37  gas_co2                                    3336 non-null   float64
#  38  gas_co2_per_capita                         3224 non-null   float64
#  39  ghg_excluding_lucf_per_capita              620 non-null    float64
#  40  ghg_per_capita                             620 non-null    float64
#  41  land_use_change_co2                        3440 non-null   float64
#  42  land_use_change_co2_per_capita             3440 non-null   float64
#  43  methane                                    620 non-null    float64
#  44  methane_per_capita                         620 non-null    float64
#  45  nitrous_oxide                              620 non-null    float64
#  46  nitrous_oxide_per_capita                   620 non-null    float64
#  47  oil_co2                                    3336 non-null   float64
#  48  oil_co2_per_capita                         3224 non-null   float64
#  49  other_co2_per_capita                       532 non-null    float64
#  50  other_industry_co2                         532 non-null    float64
#  51  primary_energy_consumption                 1120 non-null   float64
#  52  share_global_cement_co2                    2012 non-null   float64
#  53  share_global_co2                           3336 non-null   float64
#  54  share_global_co2_including_luc             2909 non-null   float64
#  55  share_global_coal_co2                      3330 non-null   float64
#  56  share_global_cumulative_cement_co2         2012 non-null   float64
#  57  share_global_cumulative_co2                3336 non-null   float64
#  58  share_global_cumulative_co2_including_luc  2909 non-null   float64
#  59  share_global_cumulative_coal_co2           3330 non-null   float64
#  60  share_global_cumulative_flaring_co2        1440 non-null   float64
#  61  share_global_cumulative_gas_co2            2625 non-null   float64
#  62  share_global_cumulative_luc_co2            3440 non-null   float64
#  63  share_global_cumulative_oil_co2            2878 non-null   float64
#  64  share_global_cumulative_other_co2          532 non-null    float64
#  65  share_global_flaring_co2                   1440 non-null   float64
#  66  share_global_gas_co2                       2625 non-null   float64
#  67  share_global_luc_co2                       3440 non-null   float64
#  68  share_global_oil_co2                       2878 non-null   float64
#  69  share_global_other_co2                     532 non-null    float64
#  70  share_of_temperature_change_from_ghg       3420 non-null   float64
#  71  temperature_change_from_ch4                3420 non-null   float64
#  72  temperature_change_from_co2                3420 non-null   float64
#  73  temperature_change_from_ghg                3420 non-null   float64
#  74  temperature_change_from_n2o                3420 non-null   float64
#  75  total_ghg                                  620 non-null    float64
#  76  total_ghg_excluding_lucf                   620 non-null    float64
#  77  trade_co2                                  620 non-null    float64
#  78  trade_co2_share                            620 non-null    float64
# dtypes: float64(76), int64(1), object(2)
# memory usage: 2.4+ MB
#              country  year   population       co2  co2_per_capita
# 48064  United States  1927  115040131.0  1862.839          16.193
# 48065  United States  1928  116730690.0  1830.965          15.685
# 48066  United States  1929  118261782.0  1963.506          16.603
# 48067  United States  1930  119629770.0  1744.916          14.586
# 48068  United States  1931  120830953.0  1484.959          12.290
# 48069  United States  1932  121861566.0  1257.814          10.322
# 48070  United States  1933  122717780.0  1348.877          10.992
# 48071  United States  1934  123580010.0  1436.239          11.622
# 48072  United States  1935  124448298.0  1492.321          11.991
# 48073  United States  1936  125322686.0  1713.412          13.672
# 48074  United States  1937  126203219.0  1792.610          14.204
# 48075  United States  1938  127089938.0  1515.750          11.927
# 48076  United States  1939  128160070.0  1670.920          13.038
# 48077  United States  1940  129417367.0  1874.985          14.488
# 48078  United States  1941  130865641.0  2043.585          15.616
# 48079  United States  1942  132508765.0  2198.265          16.590
# 48080  United States  1943  134350677.0  2272.059          16.911
# 48081  United States  1944  136218191.0  2444.904          17.948
# 48082  United States  1945  138111665.0  2359.552          17.084
# 48083  United States  1946  140031458.0  2257.494          16.121
# 48084  United States  1947  141977937.0  2485.854          17.509
# 48085  United States  1948  143951473.0  2582.559          17.940
# 48086  United States  1949  146051521.0  2164.862          14.823
# 48087  United States  1950  148281552.0  2541.485          17.140
# 48088  United States  1951  150598448.0  2618.711          17.389
# 48089  United States  1952  152941728.0  2551.219          16.681
# 48090  United States  1953  155451200.0  2612.971          16.809
# 48091  United States  1954  158205872.0  2489.462          15.736
# 48092  United States  1955  161136448.0  2728.512          16.933
# 48093  United States  1956  164063408.0  2859.995          17.432
# 48094  United States  1957  166949120.0  2835.772          16.986
# 48095  United States  1958  170147104.0  2747.108          16.145
# 48096  United States  1959  173324608.0  2831.923          16.339
# 48097  United States  1960  176188576.0  2897.315          16.444
# 48098  United States  1961  179087280.0  2886.873          16.120
# 48099  United States  1962  181917808.0  2993.902          16.457
# 48100  United States  1963  184649872.0  3126.488          16.932
# 48101  United States  1964  187277376.0  3264.313          17.430
# 48102  United States  1965  189703280.0  3399.547          17.920
# 48103  United States  1966  191830976.0  3571.421          18.618
# 48104  United States  1967  193782432.0  3705.461          19.122
# 48105  United States  1968  195743424.0  3840.919          19.622
# 48106  United States  1969  197859328.0  4035.145          20.394
# 48107  United States  1970  200328336.0  4339.686          21.663
# 48108  United States  1971  202907920.0  4365.465          21.515
# 48109  United States  1972  205238384.0  4573.015          22.281
# 48110  United States  1973  207314768.0  4785.048          23.081
# 48111  United States  1974  209277968.0  4621.046          22.081
# 48112  United States  1975  211274544.0  4478.226          21.196
# 48113  United States  1976  213270032.0  4747.762          22.262

# %% [markdown]
# ## Cumulative emissions over time

# %%
df0_Top20_all_years = df0_Top20
df0_Top20 = df0_Top20[df0_Top20['year']>1950]

# %%
import plotly.express as px

fig = px.line(df0_Top20, x = 'year', y = 'cumulative_co2', color = 'country', template='plotly_white', height=600, width=1200)
fig.update_traces(line={'width': 3})

# %% [markdown]
# ## Annual emissions to 2021

# %%
fig = px.line(df0_Top20, x = 'year', y = 'co2', color = 'country', template='plotly_white', height=600, width=1200)
fig.update_traces(line={'width': 3})

# %% [markdown]
# ## Cumlative to... select year

# %%
year = 2021
fig = px.line(df0_Top20_all_years[df0_Top20_all_years['year'] < year], 
              x = 'year', y = 'cumulative_co2', color = 'country', 
              title = "Cumulative emissions since 1950",
              template='plotly_white', height=600, width=1200)
fig.update_traces(line={'width': 3})

# %% [markdown]
# ## Annual to... select year

# %%
year = 2021
fig = px.line(df0_Top20_all_years[df0_Top20_all_years['year'] < year], 
        x = 'year', y = 'co2', color = 'country', 
        title = "Annual emissions by country",
        template='plotly_white', height=600, width=1200)
fig.update_traces(line={'width': 3})

# %% [markdown]
# ## Cumulative Emissions 2021

# %%
df0_Top20_2021 = df0_Top20[df0_Top20['year'] == 2021].sort_values('cumulative_co2')
fig = px.bar(x=df0_Top20_2021['country'],y=df0_Top20_2021['cumulative_co2'], 
    color = df0_Top20_2021['country'], title = "Cumulative Emissions to 2021",
    template='plotly_white', height=600, width=1200)
fig.update_layout(showlegend=False)
fig

# %% [markdown]
# ## Emissions per capita 2021

# %%
df0_Top20_2021 = df0_Top20[df0_Top20['year'] == 2021].sort_values('co2_per_capita')
fig = px.bar(x=df0_Top20_2021['country'],y=df0_Top20_2021['co2_per_capita'], color = df0_Top20_2021['country'], 
             title = "Emissions per capita 2021",
             template='plotly_white', height=600, width=1200)
fig.update_layout(showlegend=False)
fig

# %% [markdown]
# ## Population 2021

# %%
df0_Top20_2021 = df0_Top20[df0_Top20['year'] == 2021].sort_values('population')
fig = px.bar(x=df0_Top20_2021['country'],y=df0_Top20_2021['population'], color = df0_Top20_2021['country'], 
             title = "Population 2021",
             template='plotly_white', height=600, width=1200)
fig.update_layout(showlegend=False)
fig

# %%
import entities
df_economic = pd.read_csv('owid-co2-data.csv')
df_economic = df_economic[df_economic['country'].isin(entities.economic_entities)]
df_economic
fig = px.line(df_economic, x = 'year', y = 'co2', color = 'country', 
              title = "Emissions by economic ranking",
              template='plotly_white', height=600, width=1200)
fig.update_traces(line={'width': 3})

# %% [markdown]
# ## World total emissions

# %%
df_countries = pd.read_csv('owid-co2-data.csv')
df_world = df_countries[df_countries['country']=='World']
tot_emissions_2021 = float(df_world[df_world['year'] == 2021]['co2'])
tot_emissions_2021
# Out:
# 37123.852

# %% [markdown]
# ## List of countries with CO2/CO2 per capita emissions

# %%
df_countries = df_countries[df_countries['country'].isin(entities.countries)]

lst = ['country','year','co2','co2_per_capita']
country_data = df_countries[df_countries.columns.intersection(lst)]
country_data
#country_data.sort_values(by = 'co2', ascending=False)
# Out:
#            country  year     co2  co2_per_capita
# 0      Afghanistan  1850     NaN             NaN
# 1      Afghanistan  1851     NaN             NaN
# 2      Afghanistan  1852     NaN             NaN
# 3      Afghanistan  1853     NaN             NaN
# 4      Afghanistan  1854     NaN             NaN
# ...            ...   ...     ...             ...
# 50593     Zimbabwe  2017   9.596           0.651
# 50594     Zimbabwe  2018  11.795           0.784
# 50595     Zimbabwe  2019  11.115           0.724
# 50596     Zimbabwe  2020  10.608           0.677
# 50597     Zimbabwe  2021  11.296           0.706
#
# [42313 rows x 4 columns]

# %% [markdown]
# ## All countries with < 2% of global emissions add up to 36% of total

# %%
country_data_2021 = country_data[country_data['year'] == 2021]
print(country_data_2021.sort_values(by = 'co2', ascending=False))

tot_2pc_countries = country_data_2021[country_data_2021['co2'] <= tot_emissions_2021*0.02]['co2'].sum()

tot_2pc_countries/tot_emissions_2021
# Out:
#                             country  year        co2  co2_per_capita
# 9425                          China  2021  11472.368           8.046
# 48158                 United States  2021   5007.336          14.859
# 21465                         India  2021   2709.684           1.925
# 38579                        Russia  2021   1755.547          12.099
# 23184                         Japan  2021   1067.398           8.566
# ...                             ...   ...        ...             ...
# 37787                   Puerto Rico  2021        NaN             NaN
# 39630    Saint Martin (French part)  2021        NaN             NaN
# 44444        Svalbard and Jan Mayen  2021        NaN             NaN
# 48330  United States Virgin Islands  2021        NaN             NaN
# 49809                Western Sahara  2021        NaN             NaN
#
# [233 rows x 4 columns]
# 0.3593617117103043

# %% [markdown]
# ## All countries with > 2% of global emissions of total - there are 6

# %%
tot_98pc_countries = country_data_2021[country_data_2021['co2'] > tot_emissions_2021*0.02]
tot_98pc_countries.sort_values(by = 'co2', ascending=False)
# Out:
#              country  year        co2  co2_per_capita
# 9425           China  2021  11472.368           8.046
# 48158  United States  2021   5007.336          14.859
# 21465          India  2021   2709.684           1.925
# 38579         Russia  2021   1755.547          12.099
# 23184          Japan  2021   1067.398           8.566
# 21980           Iran  2021    748.879           8.517

# %%
tot_98pc_countries['co2'].sum()/tot_emissions_2021
# Out:
# 0.6131155786312261

# %%
reduced_list = tot_98pc_countries.append({'country': '2percenters', 'year': 2021, 'co2': tot_2pc_countries}, ignore_index=True)
reduced_list
# Out:
# C:\Users\jones\AppData\Local\Temp\ipykernel_36196\1358542477.py:1: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#          country  year        co2  co2_per_capita
# 0          China  2021  11472.368           8.046
# 1          India  2021   2709.684           1.925
# 2           Iran  2021    748.879           8.517
# 3          Japan  2021   1067.398           8.566
# 4         Russia  2021   1755.547          12.099
# 5  United States  2021   5007.336          14.859
# 6    2percenters  2021  13340.891             NaN

# %%
fig = px.bar(reduced_list.sort_values(by = 'co2', ascending=False), 
             x = 'country', y = 'co2', 
             color = 'country', 
             template='plotly_white', height=600, width=1200)
fig.update_layout(showlegend=False)
fig

# %%
fig = px.pie(reduced_list.sort_values(by = 'co2', ascending=False), 
              values = 'co2', names = 'country',
             template='plotly_white', height=600, width=600)
fig.update_traces(textposition='inside', textinfo='label+percent')
fig

# %%
df0[df0['year']==2000]
# Out:
#               country  year iso_code    population           gdp  cement_co2  \
# 150       Afghanistan  2000      AFG  1.954299e+07  1.128379e+10       0.010
# 422            Africa  2000      NaN  8.189524e+08           NaN      31.310
# 594      Africa (GCP)  2000      NaN           NaN           NaN         NaN
# 766     Aland Islands  2000      ALA           NaN           NaN         NaN
# 938           Albania  2000      ALB  3.182027e+06  1.521426e+10       0.094
# ...               ...   ...      ...           ...           ...         ...
# 49788  Western Sahara  2000      ESH  2.703890e+05           NaN         NaN
# 50060           World  2000      NaN  6.148899e+09  5.986666e+13     721.927
# 50232           Yemen  2000      YEM  1.862870e+07  7.775042e+10       0.541
# 50404          Zambia  2000      ZMB  9.891140e+06  1.496412e+10       0.154
# 50576        Zimbabwe  2000      ZWE  1.183468e+07  2.676498e+10       0.404
#
#        cement_co2_per_capita        co2  co2_growth_abs  co2_growth_prct  ...  \
# 150                    0.001      1.047          -0.045           -4.078  ...
# 422                    0.038    886.403          55.992            6.743  ...
# 594                      NaN    886.392             NaN              NaN  ...
# 766                      NaN        NaN             NaN              NaN  ...
# 938                    0.029      3.025           0.039            1.297  ...
# ...                      ...        ...             ...              ...  ...
# 49788                    NaN        NaN             NaN              NaN  ...
# 50060                  0.117  25453.623         721.234            2.916  ...
# 50232                  0.029     14.494           0.770            5.609  ...
# 50404                  0.016      1.784           0.007            0.366  ...
# 50576                  0.034     13.818          -1.910          -12.141  ...
#
#        share_global_other_co2  share_of_temperature_change_from_ghg  \
# 150                       NaN                                 0.080
# 422                       NaN                                 8.746
# 594                       NaN                                   NaN
# 766                       NaN                                   NaN
# 938                       NaN                                 0.031
# ...                       ...                                   ...
# 49788                     NaN                                   NaN
# 50060                   100.0                               100.000
# 50232                     NaN                                 0.043
# 50404                     NaN                                 0.228
# 50576                     NaN                                 0.121
#
#        temperature_change_from_ch4  temperature_change_from_co2  \
# 150                          0.000                        0.000
# 422                          0.040                        0.052
# 594                            NaN                          NaN
# 766                            NaN                          NaN
# 938                          0.000                        0.000
# ...                            ...                          ...
# 49788                          NaN                          NaN
# 50060                        0.321                        0.757
# 50232                        0.000                        0.000
# 50404                        0.001                        0.002
# 50576                        0.000                        0.001
#
#        temperature_change_from_ghg  temperature_change_from_n2o  total_ghg  \
# 150                          0.001                        0.000      11.82
# 422                          0.099                        0.007    3119.22
# 594                            NaN                          NaN        NaN
# 766                            NaN                          NaN        NaN
# 938                          0.000                        0.000       8.42
# ...                            ...                          ...        ...
# 49788                          NaN                          NaN        NaN
# 50060                        1.135                        0.058   35994.91
# 50232                        0.000                        0.000      34.70
# 50404                        0.003                        0.000      45.42
# 50576                        0.001                        0.000      41.46
#
#        total_ghg_excluding_lucf  trade_co2  trade_co2_share
# 150                       14.21        NaN              NaN
# 422                     2063.54   -167.010          -18.841
# 594                         NaN        NaN              NaN
# 766                         NaN        NaN              NaN
# 938                        8.16      1.066           35.240
# ...                         ...        ...              ...
# 49788                       NaN        NaN              NaN
# 50060                  34208.32     -0.002           -0.000
# 50232                     34.70        NaN              NaN
# 50404                     22.88      2.113          118.450
# 50576                     31.04     -1.558          -11.277
#
# [271 rows x 79 columns]

# %%
df0['gdp_per_capita'] = df0['gdp']/df0['population']
#temp = df0[df0['year'1900]
px.scatter(df0[df0['year']>2013], x='co2_per_capita', y = 'gdp_per_capita', trendline='ols',
    template='plotly_white', height=600, width=1200)

# %%
px.scatter(df0[df0['year']>2013], x='co2', y = 'gdp', trendline='ols',
    template='plotly_white', height=600, width=1200)
